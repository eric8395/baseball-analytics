# %% [markdown]
# # Teams Advanced Modeling

# %%
# import libraries 
import pandas as pd
import numpy as np
import math
from scipy.stats import kurtosis, skew

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.metrics import r2_score, mean_squared_error

from sklearn.preprocessing import OneHotEncoder, StandardScaler, MaxAbsScaler, MinMaxScaler, PolynomialFeatures
from sklearn.impute import SimpleImputer

from sklearn.pipeline import Pipeline

# this will allow us to visualize the pipeline (may not be available in learn-env)
from sklearn import set_config
set_config(display= 'diagram')

from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, \
RandomizedSearchCV, StratifiedKFold, KFold
from sklearn.feature_selection import SelectFromModel

from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, \
AdaBoostClassifier, GradientBoostingClassifier

from pickle import dump, load

# ignore warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

pd.set_option('display.max_columns', None)

np.random_state = 42

# %%
# load batting_basic
team_adv_merged = pd.read_csv('Data/team_adv_merged', index_col = 0)

# remove extra features that wont be modelled
team_adv_merged = team_adv_merged.drop(columns = ['Team', 'Year', 'Losses', 'Dollars_p'])

# remove attendance = 0 rows
team_adv_merged = team_adv_merged[team_adv_merged['Attendance'] > 0]

team_adv_merged
# Out:
#      Attendance   Wins  ERA_p    G_p   GS_p  CG_p  ShO_p  SV_p  BS_p    IP_p  \
# 0     2073730.0   64.0   4.26  650.0  162.0   2.0    1.0  35.0  20.0  1444.1
# 1     2354305.0   79.0   3.38  634.0  162.0   5.0    2.0  54.0  13.0  1455.0
# 2     2464473.0   96.0   3.44  641.0  162.0   3.0    2.0  53.0  19.0  1461.1
# 3     2956089.0   71.0   4.01  655.0  162.0   3.0    2.0  36.0  18.0  1465.2
# 4     1650821.0   73.0   4.30  615.0  162.0   3.0    0.0  36.0  21.0  1441.0
# ..          ...    ...    ...    ...    ...   ...    ...   ...   ...     ...
# 235   2102530.0   90.0   4.00  718.0  162.0   3.0    1.0  50.0  21.0  1417.0
# 236    761072.0  100.0   3.67  693.0  162.0   1.0    0.0  42.0  22.0  1455.2
# 237   2110258.0   60.0   4.80  669.0  162.0   0.0    0.0  31.0  18.0  1424.1
# 238    805901.0   91.0   3.91  698.0  162.0   1.0    1.0  34.0  18.0  1405.1
# 239   1465543.0   65.0   4.82  731.0  162.0   1.0    0.0  36.0  34.0  1394.1
#
#       TBF_p     H_p    R_p   ER_p   HR_p   BB_p  IBB_p  HBP_p  WP_p  BK_p  \
# 0    6162.0  1467.0  742.0  683.0  154.0  469.0   43.0   51.0  50.0   5.0
# 1    6087.0  1369.0  597.0  547.0  121.0  472.0   36.0   37.0  75.0   1.0
# 2    6104.0  1342.0  593.0  558.0  151.0  472.0   25.0   59.0  42.0   2.0
# 3    6231.0  1458.0  715.0  653.0  154.0  482.0   19.0   47.0  51.0   5.0
# 4    6255.0  1468.0  758.0  688.0  140.0  557.0   42.0   69.0  75.0   3.0
# ..      ...     ...    ...    ...    ...    ...    ...    ...   ...   ...
# 235  6046.0  1234.0  672.0  629.0  152.0  608.0   30.0   85.0  66.0   4.0
# 236  5998.0  1264.0  651.0  594.0  184.0  436.0   27.0   55.0  64.0   6.0
# 237  6103.0  1402.0  815.0  760.0  232.0  513.0   11.0   61.0  67.0   0.0
# 238  5916.0  1257.0  663.0  610.0  209.0  473.0   10.0   75.0  54.0   4.0
# 239  6073.0  1364.0  820.0  747.0  247.0  548.0   46.0   71.0  43.0   1.0
#
#        SO_p    GB_p    FB_p   LD_p  IFFB_p  Balls_p  Strikes_p  Pitches_p  \
# 0    1278.0  1964.0  1390.0  908.0   102.0   8327.0    14972.0    23299.0
# 1    1301.0  1772.0  1461.0  917.0   116.0   8376.0    14959.0    23335.0
# 2    1174.0  1891.0  1540.0  883.0   160.0   8620.0    15161.0    23781.0
# 3    1213.0  1920.0  1554.0  926.0   181.0   8517.0    15261.0    23778.0
# 4    1152.0  2030.0  1487.0  883.0   131.0   9158.0    15296.0    24454.0
# ..      ...     ...     ...    ...     ...      ...        ...        ...
# 235  1225.0  1780.0  1409.0  882.0   125.0   8860.0    14559.0    23419.0
# 236  1478.0  1654.0  1500.0  829.0   165.0   7902.0    15268.0    23170.0
# 237  1239.0  1796.0  1561.0  877.0   143.0   8471.0    15115.0    23586.0
# 238  1468.0  1668.0  1443.0  767.0   157.0   8506.0    15043.0    23549.0
# 239  1346.0  1649.0  1546.0  828.0   160.0   8774.0    14958.0    23732.0
#
#       RS_p  IFH_p   BU_p  BUH_p  K/9_p  BB/9_p  K/BB_p  H/9_p  HR/9_p  AVG_p  \
# 0    615.0  116.0  101.0   21.0   7.96    2.92    2.72   9.14    0.96  0.260
# 1    573.0  102.0  126.0   30.0   8.05    2.92    2.76   8.47    0.75  0.245
# 2    705.0  133.0   84.0   30.0   7.23    2.91    2.49   8.27    0.93  0.241
# 3    634.0  126.0   88.0   24.0   7.45    2.96    2.52   8.95    0.95  0.256
# 4    660.0  142.0   77.0   23.0   7.20    3.48    2.07   9.17    0.87  0.261
# ..     ...    ...    ...    ...    ...     ...     ...    ...     ...    ...
# 235  706.0   94.0   57.0    9.0   7.78    3.86    2.01   7.84    0.97  0.231
# 236  857.0  106.0   45.0   14.0   9.14    2.70    3.39   7.81    1.14  0.230
# 237  625.0  115.0   53.0   22.0   7.83    3.24    2.42   8.86    1.47  0.254
# 238  846.0  128.0   22.0    8.0   9.40    3.03    3.10   8.05    1.34  0.234
# 239  724.0  124.0   81.0   10.0   8.69    3.54    2.46   8.80    1.59  0.250
#
#      WHIP_p  BABIP_p  LOB%_p  FIP_p  GB/FB_p  LD%_p  GB%_p  FB%_p  IFFB%_p  \
# 0      1.34    0.312   0.703   3.83     1.41  0.213  0.461  0.326    0.073
# 1      1.27    0.300   0.750   3.47     1.21  0.221  0.427  0.352    0.079
# 2      1.24    0.280   0.770   3.96     1.23  0.205  0.438  0.357    0.104
# 3      1.32    0.301   0.718   3.93     1.24  0.210  0.436  0.353    0.116
# 4      1.41    0.306   0.704   4.10     1.37  0.201  0.461  0.338    0.088
# ..      ...      ...     ...    ...      ...    ...    ...    ...      ...
# 235    1.30    0.272   0.732   4.30     1.26  0.217  0.437  0.346    0.089
# 236    1.17    0.281   0.737   3.79     1.10  0.208  0.415  0.377    0.110
# 237    1.34    0.288   0.703   4.76     1.15  0.207  0.424  0.369    0.092
# 238    1.23    0.284   0.755   4.18     1.16  0.198  0.430  0.372    0.109
# 239    1.37    0.289   0.710   4.87     1.07  0.206  0.410  0.384    0.103
#
#      HR/FB_p  IFH%_p  BUH%_p  Starting_p  Start-IP_p  Relieving_p  \
# 0      0.111   0.059   0.208        61.1       935.0         14.1
# 1      0.083   0.058   0.238       124.2      1013.4         41.8
# 2      0.098   0.070   0.357        80.6       952.5         37.3
# 3      0.099   0.066   0.273        61.6       968.7         31.2
# 4      0.094   0.070   0.299        92.6       966.5         -1.8
# ..       ...     ...     ...         ...         ...          ...
# 235    0.108   0.053   0.158        77.9       829.4         40.5
# 236    0.123   0.064   0.311       105.6       750.8         75.1
# 237    0.149   0.064   0.415        17.9       796.1         22.9
# 238    0.145   0.077   0.364       125.9       833.3         13.7
# 239    0.160   0.075   0.123        65.6       824.4         -2.6
#
#      Relief-IP_p  RAR_p  WAR_p  tERA_p  xFIP_p  WPA_p  -WPA_p  +WPA_p  RE24_p  \
# 0          502.8   75.3    8.2    4.50    3.63  -7.18 -115.10  107.92  -69.68
# 1          436.7  166.0   18.6    3.97    3.63   6.74 -106.58  113.31   41.46
# 2          503.7  117.9   12.9    4.38    3.92  12.50 -104.35  116.86   98.04
# 3          492.3   92.9   10.6    4.51    3.87   0.20 -108.58  108.78   -7.90
# 4          466.8   90.8   10.7    4.44    4.11  -9.72 -118.15  108.43  -85.27
# ..           ...    ...    ...     ...     ...    ...     ...     ...     ...
# 235        578.5  118.4   12.1    4.53    4.66   7.73 -101.96  109.69   26.20
# 236        696.7  180.8   18.7    3.83    3.97  10.31 -100.00  110.31   69.83
# 237        621.0   40.7    4.5    5.01    4.57  -4.72 -102.81   98.09  -85.65
# 238        562.0  139.7   14.6    4.47    4.06   8.04  -94.12  102.16   94.26
# 239        560.6   63.0    6.5    5.17    4.53 -11.19 -116.85  105.66 -106.59
#
#      REW_p  pLI_p  inLI_p  gmLI_p  exLI_p  Pulls_p  WPA/LI_p  Clutch_p  \
# 0    -7.21   1.03    0.92    1.07    1.14    488.0     -3.36     -3.63
# 1     4.68   1.08    0.95    1.15    1.24    472.0      2.42      3.83
# 2    10.37   1.06    0.97    1.19    1.30    479.0      4.88      6.95
# 3    -0.97   1.00    0.93    1.13    1.22    493.0     -1.86      2.06
# 4    -9.14   1.03    0.95    1.18    1.29    453.0     -6.20     -3.20
# ..     ...    ...     ...     ...     ...      ...       ...       ...
# 235   2.74   1.02    0.90    1.03    1.07    556.0      3.11      4.49
# 236   7.75   0.99    0.96    1.13    1.21    531.0      9.96      0.42
# 237  -8.47   0.90    0.85    0.95    0.98    507.0     -6.65      1.40
# 238   9.02   0.92    0.88    0.98    1.01    536.0      8.39      0.31
# 239 -10.90   1.01    0.93    1.04    1.09    569.0     -5.55     -5.56
#
#      FB% 2_p  FBv_p  SL%_p  SLv_p  CT%_p  CTv_p  CB%_p  CBv_p  CH%_p  CHv_p  \
# 0      0.626   90.0  0.127   82.1  0.008   90.1  0.108   77.9  0.128   81.1
# 1      0.608   91.7  0.153   82.6  0.026   87.2  0.111   78.4  0.100   83.1
# 2      0.634   92.1  0.159   83.3  0.024   88.3  0.068   76.6  0.069   83.7
# 3      0.560   91.4  0.081   83.5  0.109   87.1  0.094   77.1  0.096   83.3
# 4      0.534   92.0  0.109   84.6  0.072   86.1  0.100   77.8  0.161   83.9
# ..       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 235    0.521   92.6  0.174   83.9  0.077   86.7  0.115   75.5  0.094   84.2
# 236    0.432   93.6  0.272   84.0  0.119   85.7  0.066   77.8  0.102   83.3
# 237    0.526   93.0  0.199   83.5  0.057   87.1  0.096   79.2  0.119   84.6
# 238    0.548   93.8  0.173   85.7  0.056   87.6  0.103   79.3  0.113   83.4
# 239    0.532   93.2  0.216   82.9  0.082   89.3  0.093   76.3  0.069   85.1
#
#      SF%_p  SFv_p  KN%_p  KNv_p  XX%_p  PO%_p  wFB_p  wSL_p  wCT_p  wCB_p  \
# 0    0.004   84.6  0.000    0.0  0.007    0.0  -57.8    2.6   -5.1   -4.0
# 1    0.002   83.5  0.000    0.0  0.006    0.0   17.5   11.8    3.1   31.4
# 2    0.046   83.4  0.000    0.0  0.004    0.0    4.9   39.5    1.5  -14.9
# 3    0.046   83.8  0.013   73.3  0.003    0.0  -57.6   -2.1    5.0    1.3
# 4    0.025   84.7  0.000    0.0  0.007    0.0  -56.5   -9.5  -10.8   -5.6
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 235  0.018   83.5  0.001   57.2  0.004    0.0   40.0   29.6    1.8   -4.8
# 236  0.009   87.5  0.000    0.0  0.004    0.0   72.6   46.8   -8.1   12.4
# 237  0.002   83.0  0.000    0.0  0.002    0.0    5.6   -8.0   -9.2  -34.1
# 238  0.007   86.9  0.000    0.0  0.002    0.0   21.4   17.4    2.8  -16.1
# 239  0.008   87.5  0.000    0.0  0.007    0.0  -71.2   13.0  -14.9   -1.1
#
#      wCH_p  wSF_p  wKN_p  wFB/C_p  wSL/C_p  wCT/C_p  wCB/C_p  wCH/C_p  \
# 0      2.3    0.3    0.0    -0.40     0.09    -2.63    -0.16     0.08
# 1    -10.7   -1.2    0.0     0.12     0.33     0.50     1.22    -0.46
# 2     -6.6   -6.8    0.0     0.03     1.05     0.28    -0.92    -0.40
# 3      3.9   -2.1   -1.1    -0.43    -0.11     0.19     0.06     0.17
# 4      3.6    4.3    0.0    -0.44    -0.36    -0.62    -0.23     0.09
# ..     ...    ...    ...      ...      ...      ...      ...      ...
# 235   -4.5   -2.0   -0.3     0.33     0.73     0.10    -0.18    -0.20
# 236   -6.6   -5.0    0.0     0.73     0.74    -0.29     0.81    -0.28
# 237   -9.3   -1.5    0.0     0.05    -0.17    -0.68    -1.50    -0.33
# 238    4.7   -3.8    0.0     0.17     0.43     0.21    -0.66     0.18
# 239  -17.0   -0.8    0.0    -0.56     0.25    -0.77    -0.05    -1.04
#
#      wSF/C_p  wKN/C_p  O-Swing%_p  Z-Swing%_p  Swing%_p  O-Contact%_p  \
# 0       0.35     0.00       0.316       0.662     0.466         0.648
# 1      -2.23     0.00       0.315       0.670     0.474         0.648
# 2      -0.61     0.00       0.293       0.670     0.461         0.683
# 3      -0.19    -0.35       0.294       0.667     0.460         0.671
# 4       0.71     0.00       0.290       0.642     0.448         0.662
# ..       ...      ...         ...         ...       ...           ...
# 235    -0.48    -1.33       0.293       0.679     0.451         0.646
# 236    -2.32     0.00       0.347       0.691     0.493         0.620
# 237    -2.70     0.00       0.309       0.700     0.472         0.657
# 238    -2.40     0.00       0.317       0.691     0.473         0.625
# 239    -0.43     0.00       0.307       0.682     0.464         0.630
#
#      Z-Contact%_p  Contact%_p  Zone%_p  F-Strike%_p  SwStr%_p  HLD_p   SD_p  \
# 0           0.873       0.786    0.433        0.623     0.099   75.0  139.0
# 1           0.865       0.785    0.447        0.605     0.101   81.0  129.0
# 2           0.885       0.813    0.445        0.589     0.086   97.0  168.0
# 3           0.878       0.805    0.445        0.601     0.089   63.0  140.0
# 4           0.876       0.800    0.448        0.598     0.089   68.0  113.0
# ..            ...         ...      ...          ...       ...    ...    ...
# 235         0.862       0.779    0.408        0.589     0.100  106.0  151.0
# 236         0.838       0.750    0.424        0.632     0.123   85.0  182.0
# 237         0.859       0.782    0.417        0.602     0.103   64.0  105.0
# 238         0.842       0.757    0.417        0.600     0.115   58.0  129.0
# 239         0.855       0.768    0.419        0.608     0.107   92.0  123.0
#
#       MD_p  ERA-_p  FIP-_p  xFIP-_p   K%_p  BB%_p  SIERA_p  RS/9_p  E-F_p  \
# 0     74.0   111.0   103.0     98.0  0.207  0.076     3.59    3.83   0.43
# 1     68.0    93.0    97.0     98.0  0.214  0.078     3.61    3.54  -0.09
# 2     65.0    88.0   101.0    103.0  0.192  0.077     3.84    4.34  -0.52
# 3     69.0   100.0   105.0    102.0  0.195  0.077     3.81    3.89   0.08
# 4     91.0   112.0   105.0    109.0  0.184  0.089     4.04    4.12   0.20
# ..     ...     ...     ...      ...    ...    ...      ...     ...    ...
# 235   76.0    99.0   104.0    110.0  0.203  0.101     4.67    4.48  -0.31
# 236   95.0    90.0    93.0     93.0  0.246  0.073     3.84    5.30  -0.12
# 237   77.0   112.0   111.0    107.0  0.203  0.084     4.48    3.95   0.05
# 238   79.0    87.0    98.0     95.0  0.248  0.080     3.92    5.42  -0.28
# 239  112.0   113.0   114.0    107.0  0.222  0.090     4.37    4.67  -0.05
#
#      FA% (sc)_p  FT% (sc)_p  FC% (sc)_p  FS% (sc)_p  FO% (sc)_p  SI% (sc)_p  \
# 0         0.266       0.090       0.119       0.005       0.000       0.162
# 1         0.393       0.157       0.008       0.001       0.000       0.076
# 2         0.431       0.115       0.019       0.039       0.000       0.079
# 3         0.394       0.117       0.100       0.047       0.011       0.057
# 4         0.276       0.157       0.063       0.021       0.000       0.106
# ..          ...         ...         ...         ...         ...         ...
# 235       0.314       0.000       0.086       0.003       0.000       0.208
# 236       0.304       0.000       0.124       0.000       0.000       0.125
# 237       0.342       0.000       0.067       0.006       0.000       0.183
# 238       0.354       0.000       0.058       0.003       0.000       0.193
# 239       0.319       0.000       0.086       0.008       0.000       0.213
#
#      SL% (sc)_p  CU% (sc)_p  KC% (sc)_p  EP% (sc)_p  CH% (sc)_p  SC% (sc)_p  \
# 0         0.123       0.094       0.012       0.000       0.130         0.0
# 1         0.144       0.065       0.055       0.000       0.099         0.0
# 2         0.173       0.043       0.025       0.000       0.076         0.0
# 3         0.081       0.082       0.013       0.000       0.086         0.0
# 4         0.107       0.104       0.000       0.000       0.166         0.0
# ..          ...         ...         ...         ...         ...         ...
# 235       0.171       0.102       0.008       0.000       0.110         0.0
# 236       0.245       0.085       0.002       0.001       0.111         0.0
# 237       0.189       0.090       0.007       0.000       0.116         0.0
# 238       0.177       0.077       0.021       0.000       0.116         0.0
# 239       0.193       0.109       0.000       0.000       0.070         0.0
#
#      KN% (sc)_p  UN% (sc)_p  vFA (sc)_p  vFT (sc)_p  vFC (sc)_p  vFS (sc)_p  \
# 0         0.000         0.0        91.5        91.0        86.9        84.7
# 1         0.000         0.0        92.4        89.8        85.8        83.9
# 2         0.000         0.0        92.1        91.7        90.5        83.5
# 3         0.012         0.0        91.6        91.3        86.5        82.9
# 4         0.000         0.0        91.9        91.8        85.9        84.3
# ..          ...         ...         ...         ...         ...         ...
# 235       0.000         0.0        93.0         0.0        86.4        88.7
# 236       0.000         0.0        94.5         0.0        85.7         0.0
# 237       0.000         0.0        93.3         0.0        86.9        84.3
# 238       0.000         0.0        93.6         0.0        87.6        86.8
# 239       0.000         0.0        92.9         0.0        89.4        87.6
#
#      vFO (sc)_p  vSI (sc)_p  vSL (sc)_p  vCU (sc)_p  vKC (sc)_p  vEP (sc)_p  \
# 0           0.0        89.2        82.5        76.8        78.4         0.0
# 1           0.0        90.0        82.7        76.5        81.0         0.0
# 2          85.4        92.5        83.6        77.3        75.2         0.0
# 3          87.7        89.6        83.8        77.0        76.3         0.0
# 4           0.0        92.6        84.4        77.9         0.0         0.0
# ..          ...         ...         ...         ...         ...         ...
# 235         0.0        92.0        83.8        75.0        76.2         0.0
# 236         0.0        92.1        85.0        76.0        84.0        48.2
# 237         0.0        92.4        83.3        79.1        79.1        31.8
# 238         0.0        93.9        85.6        78.7        80.1         0.0
# 239         0.0        93.5        82.9        77.1         0.0        46.6
#
#      vCH (sc)_p  vSC (sc)_p  vKN (sc)_p  FA-X (sc)_p  FT-X (sc)_p  \
# 0          81.0         0.0         0.0          0.1          1.4
# 1          83.0         0.0         0.0         -3.2         -3.5
# 2          83.6         0.0         0.0         -2.1         -0.4
# 3          83.0         0.0        74.3         -1.4         -4.7
# 4          83.9         0.0        70.9         -1.4          2.4
# ..          ...         ...         ...          ...          ...
# 235        83.7         0.0         0.0         -1.6          0.0
# 236        83.6        82.3         0.0         -0.7          0.0
# 237        84.5         0.0         0.0         -1.7          0.0
# 238        83.5         0.0         0.0          0.4          0.0
# 239        85.0         0.0         0.0         -1.7          0.0
#
#      FC-X (sc)_p  FS-X (sc)_p  FO-X (sc)_p  SI-X (sc)_p  SL-X (sc)_p  \
# 0            1.8         -4.3          0.0         -6.0         -0.1
# 1           -0.3         -5.0          0.0          8.9          2.4
# 2            1.3         -6.6         -6.6          2.7          2.1
# 3            2.0         -7.0         -6.2         -0.4          2.0
# 4            0.3         -7.4          0.0         -7.5         -0.7
# ..           ...          ...          ...          ...          ...
# 235          1.1         -4.2          0.0         -3.4          0.6
# 236          0.3          0.0          0.0          1.5          2.6
# 237          0.3         -7.0          0.0         -3.7          2.2
# 238          1.0         -6.1          0.0          0.9          2.1
# 239          0.3         -5.3          0.0         -2.1          0.4
#
#      CU-X (sc)_p  KC-X (sc)_p  EP-X (sc)_p  CH-X (sc)_p  SC-X (sc)_p  \
# 0            3.7          5.9          0.0         -3.2          0.0
# 1            3.6         -0.6          0.0         -0.4          0.0
# 2            3.7          3.6          0.0         -1.3          0.0
# 3            3.9          5.5          0.0         -2.1          0.0
# 4            1.0          0.0          0.0          1.7          0.0
# ..           ...          ...          ...          ...          ...
# 235          4.3          6.3          0.0         -1.4          0.0
# 236         -4.5          2.9          3.1          2.4         -5.9
# 237          2.7          3.9         -3.3         -2.1          0.0
# 238         -0.4          1.9          0.0          2.5          0.0
# 239          5.3          0.0          0.9         -2.2          0.0
#
#      KN-X (sc)_p  FA-Z (sc)_p  FT-Z (sc)_p  FC-Z (sc)_p  FS-Z (sc)_p  \
# 0            0.0          9.0          6.8          9.9          3.9
# 1            0.0          8.6          5.2          3.9         -0.4
# 2            0.0         10.4          6.7         10.5          3.8
# 3            1.1          9.6          6.4          4.3          3.2
# 4           -5.8          9.3          5.7          5.4          0.2
# ..           ...          ...          ...          ...          ...
# 235          0.0          9.3          0.0          4.5          2.3
# 236          0.0         10.4          0.0          4.4          0.0
# 237          0.0         10.2          0.0          4.0          3.6
# 238          0.0          9.5          0.0          4.2          5.1
# 239          0.0          9.7          0.0          5.8          3.4
#
#      FO-Z (sc)_p  SI-Z (sc)_p  SL-Z (sc)_p  CU-Z (sc)_p  KC-Z (sc)_p  \
# 0            0.0          2.4          1.3         -5.1         -7.4
# 1            0.0          6.7          1.3         -4.3         -5.1
# 2            5.2          3.5          1.5         -4.7        -10.2
# 3            4.6          4.6          1.5         -5.3         -8.9
# 4            0.0          5.1          1.2         -3.8          0.0
# ..           ...          ...          ...          ...          ...
# 235          0.0          6.3          1.1         -7.4         -7.2
# 236          0.0          4.5          0.6         -4.3         -5.6
# 237          0.0          5.0          0.5         -5.5         -7.5
# 238          0.0          6.0          1.9         -5.2         -3.7
# 239          0.0          6.7          1.1         -4.6          0.0
#
#      EP-Z (sc)_p  CH-Z (sc)_p  SC-Z (sc)_p  KN-Z (sc)_p  wFA (sc)_p  \
# 0            0.0          4.3          0.0          0.0       -24.8
# 1            0.0          4.5          0.0          0.0        20.7
# 2            0.0          5.7          0.0          0.0        13.0
# 3            0.0          5.4          0.0          1.1       -43.2
# 4            0.0          4.8          0.0          5.1       -35.2
# ..           ...          ...          ...          ...         ...
# 235          0.0          5.0          0.0          0.0         5.2
# 236          9.2          4.6         -1.1          0.0        66.1
# 237          8.4          4.8          0.0          0.0        -6.9
# 238          0.0          4.2          0.0          0.0         5.6
# 239          5.8          3.7          0.0          0.0       -41.9
#
#      wFT (sc)_p  wFC (sc)_p  wFS (sc)_p  wFO (sc)_p  wSI (sc)_p  wSL (sc)_p  \
# 0         -11.2         6.0        -0.7         0.0       -19.3         2.9
# 1           4.6         1.8        -0.8         0.0        10.5        14.9
# 2          -2.6        -0.6         0.5         0.0        10.3        48.0
# 3         -13.7        11.5         1.4         0.1         9.5        -2.7
# 4          -3.8       -10.2         4.1         0.0         0.4        -2.4
# ..          ...         ...         ...         ...         ...         ...
# 235         0.0         3.8        -0.1         0.0        44.7        26.9
# 236         0.0        -3.6         0.0         0.0        18.5        36.1
# 237         0.0       -15.7        -4.9         0.0        23.9         0.6
# 238         0.0         8.5        -0.2         0.0        27.5        10.2
# 239         0.0       -12.0        -0.3         0.0       -24.0        14.5
#
#      wCU (sc)_p  wKC (sc)_p  wEP (sc)_p  wCH (sc)_p  wSC (sc)_p  wKN (sc)_p  \
# 0          -2.7         1.7         0.0         6.9         0.0         0.0
# 1          10.8        20.0         0.0        -6.1         0.0         0.0
# 2          -8.0        -7.1         0.0       -14.0         0.0         0.0
# 3           3.8         0.4         0.0         3.5         0.0        -2.0
# 4          -6.2         0.0         0.0         5.1         0.0         0.1
# ..          ...         ...         ...         ...         ...         ...
# 235         0.2        -0.1         0.0        -2.2         0.0         0.0
# 236        25.3         1.8        -0.7       -10.3         0.1         0.0
# 237       -32.2        -0.6        -0.4        -4.9         0.0         0.0
# 238        -9.7        -2.0         0.0         2.3         0.0         0.0
# 239        -0.3         0.0         0.6       -15.0         0.0         0.0
#
#      wFA/C (sc)_p  wFT/C (sc)_p  wFC/C (sc)_p  wFS/C (sc)_p  wFO/C (sc)_p  \
# 0           -0.41         -0.55          0.22         -0.71          0.00
# 1            0.23          0.13          1.01         -2.61          0.00
# 2            0.13         -0.09         -0.14          0.05         -3.85
# 3           -0.46         -0.49          0.49          0.13          0.05
# 4           -0.52         -0.10         -0.67          0.80          0.00
# ..            ...           ...           ...           ...           ...
# 235          0.07          0.00          0.19         -0.21          0.00
# 236          0.94          0.00         -0.13          0.00          0.00
# 237         -0.09          0.00         -1.00         -3.76          0.00
# 238          0.07          0.00          0.62         -0.34          0.00
# 239         -0.55          0.00         -0.59         -0.16          0.00
#
#      wSI/C (sc)_p  wSL/C (sc)_p  wCU/C (sc)_p  wKC/C (sc)_p  wEP/C (sc)_p  \
# 0           -0.52          0.11         -0.13          0.59          0.00
# 1            0.59          0.45          0.72          1.56          0.00
# 2            0.55          1.17         -0.77         -1.19          0.00
# 3            0.70         -0.14          0.20          0.12          0.00
# 4            0.02         -0.09         -0.25          0.00          0.00
# ..            ...           ...           ...           ...           ...
# 235          0.92          0.67          0.01         -0.05          0.00
# 236          0.64          0.64          1.29          4.83         -3.28
# 237          0.55          0.01         -1.52         -0.37         -6.79
# 238          0.60          0.25         -0.54         -0.40          0.00
# 239         -0.48          0.32         -0.01          0.00         14.19
#
#      wCH/C (sc)_p  wSC/C (sc)_p  wKN/C (sc)_p  O-Swing% (sc)_p  \
# 0            0.23           0.0          0.00            0.287
# 1           -0.26           0.0          0.00            0.284
# 2           -0.78           0.0          0.00            0.268
# 3            0.17           0.0         -0.72            0.266
# 4            0.13           0.0         13.08            0.268
# ..            ...           ...           ...              ...
# 235         -0.09           0.0          0.00            0.253
# 236         -0.40          12.0          0.00            0.300
# 237         -0.18           0.0          0.00            0.265
# 238          0.08           0.0          0.00            0.278
# 239         -0.91           0.0          0.00            0.263
#
#      Z-Swing% (sc)_p  Swing% (sc)_p  O-Contact% (sc)_p  Z-Contact% (sc)_p  \
# 0              0.642          0.466              0.604              0.866
# 1              0.647          0.474              0.597              0.861
# 2              0.640          0.461              0.637              0.880
# 3              0.640          0.460              0.619              0.876
# 4              0.617          0.447              0.623              0.871
# ..               ...            ...                ...                ...
# 235            0.651          0.451              0.571              0.858
# 236            0.678          0.493              0.549              0.833
# 237            0.675          0.472              0.594              0.854
# 238            0.661          0.473              0.551              0.837
# 239            0.658          0.464              0.554              0.849
#
#      Contact% (sc)_p  Zone% (sc)_p  Pace_p  RA9-WAR_p  BIP-Wins_p  LOB-Wins_p  \
# 0              0.786         0.505    21.4        2.7        -5.4         0.0
# 1              0.785         0.522    21.8       20.8        -1.8         4.0
# 2              0.812         0.518    22.6       24.8         5.3         6.6
# 3              0.804         0.518    22.8       13.2        -1.7         4.4
# 4              0.799         0.514    21.4        6.9        -3.2        -0.6
# ..               ...           ...     ...        ...         ...         ...
# 235            0.777         0.498    23.7       17.0         5.4        -0.4
# 236            0.748         0.511    23.5       21.3         3.7        -1.1
# 237            0.782         0.505    23.8        4.3         1.2        -1.4
# 238            0.755         0.508    23.8       22.9         2.3         6.0
# 239            0.767         0.510    24.3        4.2        -0.3        -1.9
#
#      FDP-Wins_p  K-BB%_p  Pull%_p  Cent%_p  Oppo%_p  Soft%_p  Med%_p  Hard%_p  \
# 0          -5.5    0.131    0.397    0.351    0.252    0.171   0.512    0.317
# 1           2.3    0.136    0.379    0.337    0.284    0.177   0.516    0.307
# 2          11.9    0.115    0.418    0.328    0.254    0.194   0.523    0.282
# 3           2.7    0.117    0.419    0.335    0.246    0.174   0.508    0.318
# 4          -3.8    0.095    0.441    0.318    0.241    0.172   0.539    0.289
# ..          ...      ...      ...      ...      ...      ...     ...      ...
# 235         5.0    0.102    0.400    0.353    0.247    0.161   0.527    0.313
# 236         2.6    0.174    0.393    0.343    0.263    0.162   0.519    0.318
# 237        -0.2    0.119    0.404    0.354    0.242    0.149   0.505    0.347
# 238         8.3    0.168    0.404    0.345    0.251    0.166   0.526    0.309
# 239        -2.2    0.131    0.377    0.354    0.269    0.165   0.506    0.329
#
#      kwERA_p  TTO%_p  CH% (pi)_p  CS% (pi)_p  CU% (pi)_p  FA% (pi)_p  \
# 0       3.69   0.309       0.127       0.000       0.112       0.231
# 1       3.63   0.311       0.099       0.000       0.086       0.373
# 2       3.89   0.294       0.066       0.000       0.071       0.428
# 3       3.86   0.297       0.091       0.001       0.089       0.392
# 4       4.13   0.296       0.162       0.000       0.098       0.339
# ..       ...     ...         ...         ...         ...         ...
# 235     4.93   0.328       0.109       0.000       0.112       0.332
# 236     4.07   0.350       0.111       0.000       0.067       0.326
# 237     4.73   0.325       0.120       0.000       0.099       0.340
# 238     4.13   0.363       0.111       0.000       0.104       0.355
# 239     4.58   0.353       0.067       0.000       0.083       0.350
#
#      FC% (pi)_p  FS% (pi)_p  KN% (pi)_p  SB% (pi)_p  SI% (pi)_p  SL% (pi)_p  \
# 0         0.144       0.004       0.000         0.0       0.252       0.116
# 1         0.012       0.003       0.000         0.0       0.241       0.182
# 2         0.015       0.049       0.000         0.0       0.206       0.154
# 3         0.112       0.049       0.013         0.0       0.168       0.082
# 4         0.094       0.021       0.000         0.0       0.188       0.080
# ..          ...         ...         ...         ...         ...         ...
# 235       0.076       0.003       0.000         0.0       0.189       0.179
# 236       0.126       0.000       0.000         0.0       0.097       0.272
# 237       0.065       0.002       0.000         0.0       0.186       0.189
# 238       0.050       0.008       0.000         0.0       0.193       0.179
# 239       0.087       0.008       0.000         0.0       0.184       0.221
#
#      XX% (pi)_p  vCH (pi)_p  vCS (pi)_p  vCU (pi)_p  vFA (pi)_p  vFC (pi)_p  \
# 0           0.0        81.7         0.0        77.8        92.6        87.9
# 1           0.0        83.9         0.0        79.3        93.6        87.9
# 2           0.0        84.5        70.1        77.8        92.9        88.6
# 3           0.0        84.0        70.6        77.9        92.6        87.8
# 4           0.0        84.6        73.8        78.5        93.0        87.5
# ..          ...         ...         ...         ...         ...         ...
# 235         0.0        84.2         0.0        75.5        93.4        86.5
# 236         0.0        83.9        66.8        77.6        94.1        86.6
# 237         0.0        84.7         0.0        79.4        93.6        87.1
# 238         0.0        83.3         0.0        79.1        93.5        87.5
# 239         0.0        85.1         0.0        77.6        93.3        89.4
#
#      vFS (pi)_p  vKN (pi)_p  vSB (pi)_p  vSI (pi)_p  vSL (pi)_p  vXX (pi)_p  \
# 0          85.5         0.0         0.0        90.6        83.4         0.0
# 1          85.9         0.0         0.0        90.9        83.0         0.0
# 2          84.1         0.0         0.0        92.8        84.1         0.0
# 3          84.5        74.0         0.0        91.5        84.0         0.0
# 4          85.1        97.3         0.0        92.6        84.0        21.1
# ..          ...         ...         ...         ...         ...         ...
# 235        88.9         0.0         0.0        91.9        84.4        95.5
# 236        85.8         0.0        83.1        93.0        84.4        86.8
# 237        83.3         0.0         0.0        92.7        83.7        80.5
# 238        86.0         0.0         0.0        93.8        85.7        87.5
# 239        87.7         0.0         0.0        93.2        82.1        88.2
#
#      CH-X (pi)_p  CS-X (pi)_p  CU-X (pi)_p  FA-X (pi)_p  FC-X (pi)_p  \
# 0           -3.6          0.0          3.8         -0.3          1.4
# 1           -0.7          0.0          3.1         -3.0         -0.2
# 2           -1.7          8.5          2.8         -1.6          2.9
# 3           -3.7         -5.0          3.4         -2.2          0.7
# 4            1.8          8.2          0.8          0.6          0.6
# ..           ...          ...          ...          ...          ...
# 235         -1.3          0.0          4.6         -1.7          1.2
# 236          2.3        -11.1         -3.9          0.2          0.3
# 237         -2.4          0.0          2.8         -1.7          0.1
# 238          2.7          0.0          0.7          0.3          0.8
# 239         -2.2          0.0          3.5         -2.1          1.1
#
#      FS-X (pi)_p  KN-X (pi)_p  SB-X (pi)_p  SI-X (pi)_p  SL-X (pi)_p  \
# 0           -3.9          0.0          0.0         -3.3         -0.8
# 1           -2.4          0.0          0.0          0.2          1.6
# 2           -6.0          0.0          0.0         -0.9          1.9
# 3           -7.2          0.3          0.0         -3.7          1.7
# 4           -6.8         -8.7          0.0         -4.2         -0.4
# ..           ...          ...          ...          ...          ...
# 235         -3.8          0.0          0.0         -3.0          1.0
# 236         -2.1          0.0         -5.7         -0.3          2.1
# 237         -4.1          0.0          0.0         -3.6          2.5
# 238         -6.3          0.0          0.0          0.9          1.9
# 239         -4.9          0.0          0.0         -0.9          1.9
#
#      XX-X (pi)_p  CH-Z (pi)_p  CS-Z (pi)_p  CU-Z (pi)_p  FA-Z (pi)_p  \
# 0            0.0          3.2          0.0         -6.3          8.4
# 1            0.0          3.6          0.0         -5.8          7.8
# 2            0.0          4.1        -11.4         -8.5          8.9
# 3            0.0          3.2         -8.1         -8.2          8.2
# 4           -0.7          3.3        -10.8         -5.3          7.7
# ..           ...          ...          ...          ...          ...
# 235         -7.5          3.6          0.0         -9.1          8.1
# 236         -3.0          2.7        -11.5         -8.3          8.8
# 237         -3.2          3.4          0.0         -7.1          9.1
# 238         -2.0          2.6          0.0         -6.5          8.3
# 239         -1.7          2.1          0.0         -7.4          8.5
#
#      FC-Z (pi)_p  FS-Z (pi)_p  KN-Z (pi)_p  SB-Z (pi)_p  SI-Z (pi)_p  \
# 0            8.1          2.4          0.0          0.0          3.1
# 1            7.4         -0.1          0.0          0.0          4.9
# 2            3.0          2.0          0.0          0.0          4.4
# 3            3.4          2.0         -1.5          0.0          4.4
# 4            3.7         -1.2          5.1          0.0          3.5
# ..           ...          ...          ...          ...          ...
# 235          3.4          1.0          0.0          0.0          4.7
# 236          3.4         -0.2          0.0         -2.8          1.8
# 237          2.9          0.9          0.0          0.0          3.7
# 238          3.2          2.7          0.0          0.0          4.7
# 239          4.5          1.9          0.0          0.0          4.9
#
#      SL-Z (pi)_p  XX-Z (pi)_p  wCH (pi)_p  wCS (pi)_p  wCU (pi)_p  wFA (pi)_p  \
# 0            0.3          0.0         6.3         0.0         4.8        16.2
# 1           -0.7          0.0        -2.5         0.0        -2.9        35.8
# 2           -0.1          0.0        -3.1         0.0        -9.7        29.1
# 3           -1.2          0.0        -2.7        -0.1         1.0        32.3
# 4           -1.3          1.3        -6.5        -0.1        -7.6        27.5
# ..           ...          ...         ...         ...         ...         ...
# 235         -0.1          5.1        -1.4         0.0        -4.8         5.2
# 236         -0.9         -0.8        -9.7         0.0        17.9        61.8
# 237         -1.0          6.6        -7.5         0.0       -32.8        -5.0
# 238          0.5          3.9         5.8         0.0       -14.0         3.4
# 239         -0.8          5.5       -18.1         0.0        -2.1       -40.1
#
#      wFC (pi)_p  wFS (pi)_p  wKN (pi)_p  wSB (pi)_p  wSI (pi)_p  wSL (pi)_p  \
# 0           9.9        -0.1         0.0         0.0        12.7        -1.9
# 1           0.0        -0.2         0.0         0.0        13.3        -2.6
# 2          -0.2        -4.6         0.0         0.0        11.0         4.8
# 3           6.4         0.3        -0.8         0.0         4.7         0.0
# 4           1.6         0.5         0.1         0.0         9.0        -1.7
# ..          ...         ...         ...         ...         ...         ...
# 235         5.5        -0.2         0.0         0.0        43.8        29.1
# 236        -4.2         0.4         0.0         0.1        14.3        51.3
# 237       -10.5        -2.2         0.0         0.0        23.0        -3.7
# 238         9.0        -0.9         0.0         0.0        26.3        13.1
# 239       -11.9         0.7         0.0         0.0       -23.9        17.4
#
#      wXX (pi)_p  wCH/C (pi)_p  wCS/C (pi)_p  wCU/C (pi)_p  wFA/C (pi)_p  \
# 0           0.0          0.22          0.00          0.19          0.31
# 1           0.0         -0.11          0.00         -0.15          0.42
# 2           0.0         -0.20         -0.75         -0.57          0.29
# 3          -0.1         -0.12         -0.51          0.05          0.35
# 4           0.1         -0.17         -2.48         -0.32          0.33
# ..          ...           ...           ...           ...           ...
# 235        -0.1         -0.06          0.00         -0.18          0.07
# 236         0.0         -0.38         -2.85          1.15          0.82
# 237         0.0         -0.27          0.00         -1.40         -0.06
# 238        -0.4          0.22          0.00         -0.57          0.04
# 239        -0.1         -1.14          0.00         -0.11         -0.49
#
#      wFC/C (pi)_p  wFS/C (pi)_p  wKN/C (pi)_p  wSB/C (pi)_p  wSI/C (pi)_p  \
# 0            0.30         -0.05          0.00           0.0          0.22
# 1           -0.01         -0.26          0.00           0.0          0.24
# 2           -0.05         -0.40          0.00           0.0          0.23
# 3            0.24          0.02         -0.26           0.0          0.12
# 4            0.07          0.09          7.04           0.0          0.20
# ..            ...           ...           ...           ...           ...
# 235          0.31         -0.42          0.00           0.0          0.99
# 236         -0.14         12.27          0.00          12.0          0.63
# 237         -0.69         -5.68          0.00           0.0          0.52
# 238          0.77         -0.48          0.00           0.0          0.58
# 239         -0.58          0.37          0.00           0.0         -0.55
#
#      wSL/C (pi)_p  wXX/C (pi)_p  O-Swing% (pi)_p  Z-Swing% (pi)_p  \
# 0           -0.07         -2.24            0.287            0.633
# 1           -0.06         -1.93            0.281            0.646
# 2            0.13          0.00            0.266            0.641
# 3            0.00         -4.10            0.267            0.635
# 4           -0.08          2.92            0.269            0.613
# ..            ...           ...              ...              ...
# 235          0.69         -1.28            0.252            0.644
# 236          0.81          0.28            0.303            0.669
# 237         -0.08         -0.67            0.270            0.666
# 238          0.31         -6.18            0.283            0.655
# 239          0.33         -1.11            0.268            0.649
#
#      Swing% (pi)_p  O-Contact% (pi)_p  Z-Contact% (pi)_p  Contact% (pi)_p  \
# 0            0.466              0.605              0.862            0.786
# 1            0.473              0.595              0.860            0.785
# 2            0.461              0.630              0.882            0.812
# 3            0.460              0.618              0.876            0.804
# 4            0.447              0.629              0.868            0.799
# ..             ...                ...                ...              ...
# 235          0.451              0.565              0.858            0.778
# 236          0.493              0.550              0.831            0.748
# 237          0.472              0.593              0.855            0.782
# 238          0.473              0.556              0.837            0.755
# 239          0.464              0.556              0.850            0.768
#
#      Zone% (pi)_p  Pace (pi)_p  FRM_p  K/9+_p  BB/9+_p  K/BB+_p  H/9+_p  \
# 0           0.518         21.4   20.5   102.0    101.0    101.0   107.0
# 1           0.527         21.8  -18.7   103.0    101.0    102.0    99.0
# 2           0.520         22.6    6.0    94.0    100.0     94.0    95.0
# 3           0.524         22.8   14.0    97.0    102.0     95.0   103.0
# 4           0.518         21.4    1.7    94.0    119.0     78.0   106.0
# ..            ...          ...    ...     ...      ...      ...     ...
# 235         0.508         23.7   -7.9    87.0    113.0     76.0    95.0
# 236         0.521         23.5    5.1   103.0     83.0    123.0    93.0
# 237         0.511         23.8   16.7    89.0     99.0     88.0   105.0
# 238         0.510         23.8    5.0   106.0     93.0    114.0    95.0
# 239         0.516         24.3   -6.8    97.0    104.0     93.0   107.0
#
#      HR/9+_p  AVG+_p  WHIP+_p  BABIP+_p  LOB%+_p  K%+_p  BB%+_p  LD%+_p  \
# 0      114.0   106.0    106.0     106.0     96.0  101.0   100.0   102.0
# 1       89.0   100.0    100.0     102.0    102.0  104.0   102.0   106.0
# 2      105.0    97.0     97.0      95.0    106.0   95.0   102.0    99.0
# 3      106.0   103.0    103.0     102.0     99.0   97.0   102.0   102.0
# 4       98.0   105.0    109.0     103.0     97.0   91.0   117.0    97.0
# ..       ...     ...      ...       ...      ...    ...     ...     ...
# 235     79.0    97.0    100.0      95.0    101.0   87.0   113.0   104.0
# 236     89.0    94.0     90.0      96.0    102.0  107.0    85.0   102.0
# 237    114.0   104.0    103.0      99.0     98.0   88.0    99.0   101.0
# 238    104.0    96.0     95.0      97.0    105.0  108.0    94.0    97.0
# 239    130.0   105.0    106.0     101.0     98.0   95.0   102.0    99.0
#
#      GB%+_p  FB%+_p  HR/FB%+_p  Pull%+_p  Cent%+_p  Oppo%+_p  Soft%+_p  \
# 0     100.0    98.0      114.0     101.0     101.0      97.0      93.0
# 1      93.0   106.0       86.0      96.0      97.0     109.0      96.0
# 2     100.0   100.0      105.0     102.0      97.0     101.0     107.0
# 3     100.0    99.0      106.0     102.0      99.0      98.0      96.0
# 4     106.0    95.0      101.0     107.0      94.0      96.0      94.0
# ..      ...     ...        ...       ...       ...       ...       ...
# 235   100.0    97.0       79.0     101.0     100.0      99.0      97.0
# 236    98.0   101.0       91.0      98.0      99.0     105.0      99.0
# 237   100.0    99.0      111.0     101.0     102.0      97.0      91.0
# 238   102.0   100.0      108.0     101.0      99.0     100.0     101.0
# 239    94.0   108.0      117.0      95.0     101.0     108.0      99.0
#
#      Med%+_p  Hard%+_p  EV_p  LA_p  Barrels_p  Barrel%_p  maxEV_p  HardHit_p  \
# 0       98.0     107.0   0.0   0.0        0.0      0.000      0.0        0.0
# 1       99.0     104.0   0.0   0.0        0.0      0.000      0.0        0.0
# 2       98.0      98.0   0.0   0.0        0.0      0.000      0.0        0.0
# 3       96.0     111.0   0.0   0.0        0.0      0.000      0.0        0.0
# 4      101.0     101.0   0.0   0.0        0.0      0.000      0.0        0.0
# ..       ...       ...   ...   ...        ...        ...      ...        ...
# 235    103.0      97.0  88.6  11.9      291.0      0.070    117.1     1544.0
# 236    101.0      99.0  88.5  13.6      341.0      0.085    118.6     1491.0
# 237     98.0     108.0  89.3  13.0      337.0      0.079    118.5     1677.0
# 238    102.0      96.0  88.9  12.6      330.0      0.085    120.2     1528.0
# 239     99.0     103.0  89.0  13.3      381.0      0.093    116.0     1622.0
#
#      HardHit%_p  Events_p  CStr%_p  CSW%_p  Age_b    AB_b    PA_b     H_b  \
# 0         0.000       0.0    0.174   0.273   28.0  5552.0  6089.0  1379.0
# 1         0.000       0.0    0.165   0.266   27.0  5468.0  6064.0  1316.0
# 2         0.000       0.0    0.174   0.260   28.0  5596.0  6130.0  1434.0
# 3         0.000       0.0    0.180   0.270   29.0  5551.0  6226.0  1355.0
# 4         0.000       0.0    0.179   0.269   27.0  5543.0  6077.0  1400.0
# ..          ...       ...      ...     ...    ...     ...     ...     ...
# 235       0.374    4128.0    0.167   0.267   28.0  5351.0  6001.0  1303.0
# 236       0.370    4029.0    0.164   0.288   28.0  5507.0  6213.0  1336.0
# 237       0.391    4290.0    0.166   0.269   27.0  5405.0  5943.0  1254.0
# 238       0.392    3900.0    0.165   0.279   28.0  5476.0  6070.0  1455.0
# 239       0.395    4108.0    0.162   0.270   29.0  5385.0  6113.0  1388.0
#
#       1B_b   2B_b  3B_b   HR_b    R_b  RBI_b   BB_b  IBB_b    SO_b  HBP_b  \
# 0    955.0  259.0  47.0  118.0  615.0  573.0  398.0   31.0  1165.0   43.0
# 1    931.0  240.0  22.0  123.0  573.0  545.0  472.0   31.0  1369.0   43.0
# 2    943.0  264.0  16.0  211.0  705.0  681.0  401.0   29.0  1285.0   62.0
# 3    930.0  282.0  20.0  123.0  634.0  601.0  535.0   36.0  1337.0   68.0
# 4    934.0  279.0  32.0  155.0  660.0  625.0  417.0   33.0  1362.0   60.0
# ..     ...    ...   ...    ...    ...    ...    ...    ...     ...    ...
# 235  822.0  261.0  22.0  198.0  706.0  678.0  478.0   32.0  1341.0   86.0
# 236  790.0  288.0  36.0  222.0  857.0  810.0  585.0   27.0  1542.0   72.0
# 237  838.0  225.0  24.0  167.0  625.0  598.0  433.0   10.0  1381.0   58.0
# 238  895.0  285.0  13.0  262.0  846.0  816.0  496.0   14.0  1218.0   51.0
# 239  914.0  272.0  20.0  182.0  724.0  686.0  573.0   43.0  1303.0   84.0
#
#      SF_b  SH_b  GDP_b   SB_b  CS_b  AVG_b    GB_b    FB_b   LD_b  IFFB_b  \
# 0    36.0  56.0  115.0   86.0  33.0  0.248  2072.0  1392.0  919.0   124.0
# 1    27.0  53.0  121.0   95.0  33.0  0.241  1867.0  1360.0  849.0   102.0
# 2    36.0  35.0  112.0   44.0  20.0  0.256  1862.0  1598.0  853.0   176.0
# 3    52.0  20.0  138.0   63.0  25.0  0.244  1860.0  1492.0  895.0   144.0
# 4    38.0  19.0  127.0   85.0  36.0  0.253  1932.0  1382.0  874.0   151.0
# ..    ...   ...    ...    ...   ...    ...     ...     ...    ...     ...
# ...
# 237    0.258    0.161   0.527    0.312   0.333       0.116       0.000
# 238    0.254    0.149   0.516    0.336   0.326       0.115       0.000
# 239    0.252    0.163   0.520    0.318   0.337       0.114       0.000
#
#      CU% (pi)_b  FA% (pi)_b  FC% (pi)_b  FS% (pi)_b  KN% (pi)_b  SB% (pi)_b  \
# 0         0.089       0.352       0.093       0.026       0.000         0.0
# 1         0.098       0.355       0.091       0.018       0.000         0.0
# 2         0.098       0.337       0.063       0.037       0.014         0.0
# 3         0.089       0.353       0.057       0.027       0.018         0.0
# 4         0.100       0.354       0.085       0.018       0.004         0.0
# ..          ...         ...         ...         ...         ...         ...
# 235       0.108       0.349       0.056       0.012       0.000         0.0
# 236       0.100       0.355       0.066       0.019       0.000         0.0
# 237       0.090       0.377       0.066       0.022       0.000         0.0
# 238       0.080       0.361       0.074       0.010       0.000         0.0
# 239       0.108       0.360       0.049       0.015       0.000         0.0
#
#      SI% (pi)_b  SL% (pi)_b  XX% (pi)_b  vCH (pi)_b  vCS (pi)_b  vCU (pi)_b  \
# 0         0.210       0.135         0.0        84.2        69.7        77.8
# 1         0.203       0.149         0.0        84.3        68.8        78.5
# 2         0.204       0.146         0.0        84.5        73.9        78.7
# 3         0.225       0.134         0.0        83.8        75.7        78.6
# 4         0.191       0.140         0.0        84.3        75.0        78.7
# ..          ...         ...         ...         ...         ...         ...
# 235       0.167       0.198         0.0        85.4        76.4        79.7
# 236       0.150       0.191         0.0        85.0         0.0        80.0
# 237       0.149       0.179         0.0        84.4        70.1        79.0
# 238       0.141       0.219         0.0        84.8        72.5        79.4
# 239       0.150       0.203         0.0        85.4        74.7        79.0
#
#      vFA (pi)_b  vFC (pi)_b  vFS (pi)_b  vKN (pi)_b  vSB (pi)_b  vSI (pi)_b  \
# 0          93.1        88.6        84.2         0.0        88.6        91.9
# 1          93.5        89.4        83.6        88.2         0.0        92.0
# 2          93.0        88.4        85.4        75.8         0.0        91.9
# 3          93.0        88.7        85.2        75.8         0.0        92.3
# 4          93.2        88.9        84.8        77.0         0.0        92.0
# ..          ...         ...         ...         ...         ...         ...
# 235        93.9        89.1        85.6         0.0         0.0        93.2
# 236        94.0        88.6        86.6         0.0         0.0        93.4
# 237        93.5        88.6        86.4         0.0         0.0        93.2
# 238        93.7        87.5        86.2         0.0         0.0        93.4
# 239        94.0        88.5        85.9         0.0         0.0        93.7
#
#      vSL (pi)_b  vXX (pi)_b  CH-X (pi)_b  CS-X (pi)_b  CU-X (pi)_b  \
# 0          84.8         0.0         -2.3          6.6          3.3
# 1          84.9        37.2         -2.2          6.2          3.7
# 2          84.2         0.0         -1.6          7.3          2.7
# 3          84.1         0.0         -0.6          7.1          3.0
# 4          84.6         0.0         -1.9          6.7          3.1
# ..          ...         ...          ...          ...          ...
# 235        85.2        87.4         -3.7          8.3          3.0
# 236        84.8        85.2         -1.9          0.0          2.1
# 237        84.3        96.1         -0.7          5.9          1.6
# 238        84.7        79.3         -1.5          6.8          2.3
# 239        85.4        78.5         -3.5          8.3          2.1
#
#      FA-X (pi)_b  FC-X (pi)_b  FS-X (pi)_b  KN-X (pi)_b  SB-X (pi)_b  \
# 0           -1.8          1.0         -2.2          0.0         -4.6
# 1           -1.7          0.8         -4.9         -0.3          0.0
# 2           -1.4          1.1         -5.9         -0.4          0.0
# 3           -1.0          1.6         -5.4          0.1          0.0
# 4           -1.9          1.3         -5.5          1.4          0.0
# ..           ...          ...          ...          ...          ...
# 235         -2.1          1.2         -5.4          0.0          0.0
# 236         -0.8          0.2         -6.0          0.0          0.0
# 237         -1.4          0.9         -5.9          0.0          0.0
# 238         -1.5          0.4         -5.1          0.0          0.0
# 239         -1.8          1.0         -6.2          0.0          0.0
#
#      SI-X (pi)_b  SL-X (pi)_b  XX-X (pi)_b  CH-Z (pi)_b  CS-Z (pi)_b  \
# 0           -4.5          1.9          0.0          3.2        -11.2
# 1           -4.2          1.8          3.6          2.9        -12.1
# 2           -3.3          2.3          0.0          3.3         -9.2
# 3           -1.3          2.3          0.0          3.4        -10.9
# 4           -2.9          2.2          0.0          3.0         -9.4
# ..           ...          ...          ...          ...          ...
# 235         -5.8          2.4         -0.6          2.1        -11.5
# 236         -2.7          1.4         -0.4          3.1          0.0
# 237         -2.5          1.7         -3.1          3.0         -9.0
# 238         -5.1          2.2         -3.3          3.0        -10.3
# 239         -4.0          1.5         -4.7          2.3         -9.4
#
#      CU-Z (pi)_b  FA-Z (pi)_b  FC-Z (pi)_b  FS-Z (pi)_b  KN-Z (pi)_b  \
# 0           -7.5          8.0          4.2          1.2          0.0
# 1           -7.3          7.9          4.7          1.2          2.7
# 2           -7.1          8.5          3.9          1.1         -0.3
# 3           -6.9          8.6          4.2          1.9          1.2
# 4           -7.0          8.3          3.7          1.9          0.2
# ..           ...          ...          ...          ...          ...
# 235         -7.0          8.0          3.1          1.4          0.0
# 236         -7.1          8.5          3.6          0.6          0.0
# 237         -7.4          8.5          3.5          1.4          0.0
# 238         -7.7          8.3          3.4          0.8          0.0
# 239         -7.1          8.1          3.7          1.0          0.0
#
#      SB-Z (pi)_b  SI-Z (pi)_b  SL-Z (pi)_b  XX-Z (pi)_b  wCH (pi)_b  \
# 0            4.8          4.5         -0.3          0.0         3.6
# 1            0.0          4.7         -0.2         -4.1        -0.5
# 2            0.0          4.6         -0.5          0.0         0.1
# 3            0.0          4.9         -0.4          0.0         1.9
# 4            0.0          4.6         -0.3          0.0        -0.6
# ..           ...          ...          ...          ...         ...
# 235          0.0          3.9         -0.4          1.3        13.0
# 236          0.0          4.1         -0.1          8.7         6.2
# 237          0.0          4.0          0.0          9.2       -32.6
# 238          0.0          3.8         -0.3          8.5         3.5
# 239          0.0          3.9         -0.3         -1.1        -0.4
#
#      wCS (pi)_b  wCU (pi)_b  wFA (pi)_b  wFC (pi)_b  wFS (pi)_b  wKN (pi)_b  \
# 0           0.5         2.8       -33.1        -4.8         0.4         0.0
# 1           0.1         6.0       -29.5        -4.6         2.2         0.0
# 2          -0.1        -2.7       -28.2        -6.0         0.7         0.5
# 3           0.2         7.2       -37.3        -1.3         1.8        -0.9
# 4           0.5         2.1       -29.5        -7.3         1.6         0.1
# ..          ...         ...         ...         ...         ...         ...
# 235         1.3         5.7       -25.8        -1.6        -4.2         0.0
# 236         0.0         9.2         9.3         0.8        -6.4         0.0
# 237         1.1        -4.6       -31.9       -12.3        -4.6         0.0
# 238         0.0        30.1        41.6        -2.9         2.6         0.0
# 239         0.1        -9.0        42.6       -15.3        -3.5         0.0
#
#      wSB (pi)_b  wSI (pi)_b  wSL (pi)_b  wXX (pi)_b  wCH/C (pi)_b  \
# 0           0.0       -14.0         0.8         0.0          0.21
# 1           0.0       -10.6        -4.0         0.0         -0.03
# 2           0.0       -10.2        -7.7         0.0          0.01
# 3           0.0       -19.6         2.9         0.0          0.08
# 4           0.0       -12.1        -4.6         0.0         -0.03
# ..          ...         ...         ...         ...           ...
# 235         0.0         5.8       -17.0         0.0          0.51
# 236         0.0        31.0         0.4         0.0          0.21
# 237         0.0       -16.6       -34.8         0.0         -1.22
# 238         0.0        19.6         6.4         0.0          0.13
# 239         0.0        11.0        -5.2         0.0         -0.01
#
#      wCS/C (pi)_b  wCU/C (pi)_b  wFA/C (pi)_b  wFC/C (pi)_b  wFS/C (pi)_b  \
# 0            0.84          0.14         -0.42         -0.23          0.06
# 1            0.58          0.27         -0.37         -0.22          0.52
# 2           -0.51         -0.12         -0.36         -0.41          0.08
# 3            0.69          0.32         -0.42         -0.09          0.27
# 4            0.75          0.09         -0.36         -0.37          0.40
# ..            ...           ...           ...           ...           ...
# 235         31.81          0.23         -0.32         -0.12         -1.49
# 236          0.00          0.38          0.11          0.05         -1.36
# 237         21.74         -0.22         -0.37         -0.82         -0.90
# 238         -0.26          1.62          0.50         -0.17          1.11
# 239          3.22         -0.36          0.51         -1.33         -0.98
#
#      wKN/C (pi)_b  wSB/C (pi)_b  wSI/C (pi)_b  wSL/C (pi)_b  wXX/C (pi)_b  \
# 0            0.00          -0.1         -0.30          0.02          0.00
# 1            0.00           0.0         -0.23         -0.12          1.75
# 2            0.15           0.0         -0.22         -0.23         -0.78
# 3           -0.20           0.0         -0.35          0.09          0.00
# 4            0.11           0.0         -0.28         -0.14          1.75
# ..            ...           ...           ...           ...           ...
# 235          0.00           0.0          0.15         -0.37         -0.86
# 236          0.00           0.0          0.85          0.01          1.02
# 237          0.00           0.0         -0.49         -0.85          0.00
# 238          0.00           0.0          0.60          0.13          4.97
# 239          0.00           0.0          0.31         -0.11          2.01
#
#      O-Swing% (pi)_b  Z-Swing% (pi)_b  Swing% (pi)_b  O-Contact% (pi)_b  \
# 0              0.289            0.613          0.460              0.642
# 1              0.292            0.658          0.483              0.576
# 2              0.309            0.645          0.481              0.597
# 3              0.262            0.587          0.435              0.633
# 4              0.298            0.657          0.483              0.568
# ..               ...              ...            ...                ...
# 235            0.276            0.648          0.470              0.578
# 236            0.267            0.668          0.474              0.536
# 237            0.288            0.654          0.479              0.571
# 238            0.276            0.691          0.489              0.551
# 239            0.252            0.644          0.457              0.552
#
#      Z-Contact% (pi)_b  Contact% (pi)_b  Zone% (pi)_b  Pace (pi)_b  FRM_b  \
# 0                0.879            0.809         0.529         22.3   20.6
# 1                0.835            0.760         0.522         21.9  -18.7
# 2                0.854            0.773         0.511         22.0    6.0
# 3                0.869            0.803         0.535         22.8   14.0
# 4                0.859            0.772         0.515         22.7    1.7
# ..                 ...              ...           ...          ...    ...
# 235              0.838            0.765         0.522         23.1   -7.9
# 236              0.813            0.737         0.515         23.1    5.0
# 237              0.837            0.760         0.520         23.5   16.7
# 238              0.862            0.776         0.512         22.8    5.0
# 239              0.854            0.774         0.522         23.6   -6.8
#
#      AVG+_b  BB%+_b  K%+_b  OBP+_b  SLG+_b  ISO+_b  BABIP+_b  LD+%_b  GB%+_b  \
# 0      97.0    84.0   96.0    94.0    95.0    92.0      97.0    1.00   105.0
# 1      94.0    99.0  113.0    95.0    91.0    86.0      98.0    0.99   102.0
# 2     101.0    85.0  106.0    98.0   108.0   121.0      99.0    0.95    98.0
# 3      96.0   111.0  109.0   100.0    94.0    91.0     100.0    1.02    99.0
# 4     100.0    89.0  114.0    98.0   102.0   106.0     103.0    1.01   105.0
# ..      ...     ...    ...     ...     ...     ...       ...     ...     ...
# 235    98.0    87.0  100.0    96.0    98.0    98.0      97.0    0.98    95.0
# 236    99.0   111.0  108.0   101.0   103.0   110.0     101.0    0.92   100.0
# 237    94.0    86.0  102.0    93.0    90.0    84.0      96.0    0.92   109.0
# 238   108.0    96.0   88.0   104.0   112.0   118.0     102.0    1.01    95.0
# 239   104.0   102.0   96.0   103.0    99.0    93.0     104.0    1.04   111.0
#
#      FB%+_b  HR/FB%+_b  Pull%+_b  Cent%+_b  Oppo%+_b  Soft%+_b  Med%+_b  \
# 0      93.0       87.0      93.0     105.0     104.0     100.0    103.0
# 1      98.0       93.0      99.0     101.0     101.0     103.0    100.0
# 2     105.0      139.0     103.0     100.0      95.0     100.0     97.0
# 3     100.0       87.0     101.0     102.0      95.0      93.0     96.0
# 4      94.0      118.0      97.0      98.0     108.0     109.0     98.0
# ..      ...        ...       ...       ...       ...       ...      ...
# 235   107.0       92.0     104.0      98.0      96.0      98.0    102.0
# 236   104.0      106.0      99.0     104.0      96.0     109.0     95.0
# 237    93.0       88.0      95.0     104.0     103.0      99.0    102.0
# 238   105.0      116.0     102.0      97.0     102.0      91.0    100.0
# 239    85.0      106.0      92.0     107.0     102.0      99.0    102.0
#
#      Hard%+_b  EV_b  LA_b  Barrels_b  Barrel%_b  maxEV_b  HardHit_b  \
# 0        95.0   0.0   0.0        0.0      0.000      0.0        0.0
# 1        99.0   0.0   0.0        0.0      0.000      0.0        0.0
# 2       106.0   0.0   0.0        0.0      0.000      0.0        0.0
# 3       111.0   0.0   0.0        0.0      0.000      0.0        0.0
# 4        97.0   0.0   0.0        0.0      0.000      0.0        0.0
# ..        ...   ...   ...        ...        ...      ...        ...
# 235      98.0  88.7  14.0      323.0      0.079    115.0     1523.0
# 236     103.0  88.9  12.6      335.0      0.083    117.5     1596.0
# 237      97.0  87.9  10.9      270.0      0.066    115.1     1448.0
# 238     104.0  90.3  13.6      418.0      0.097    117.4     1817.0
# 239      97.0  88.6   9.5      288.0      0.069    116.6     1626.0
#
#      HardHit%_b  Events_b  CStr%_b
# 0         0.000       0.0    0.184
# 1         0.000       0.0    0.157
# 2         0.000       0.0    0.166
# 3         0.000       0.0    0.201
# 4         0.000       0.0    0.164
# ..          ...       ...      ...
# 235       0.372    4096.0    0.172
# 236       0.398    4014.0    0.156
# 237       0.356    4071.0    0.169
# 238       0.422    4305.0    0.149
# 239       0.392    4153.0    0.173
#
# [210 rows x 634 columns]

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# **Feature Selection Using `feature_selection`**

# %%
team_adv_merged.columns
# Out:
# Index(['Attendance', 'Wins', 'ERA_p', 'G_p', 'GS_p', 'CG_p', 'ShO_p', 'SV_p',
#        'BS_p', 'IP_p',
#        ...
#        'Hard%+_b', 'EV_b', 'LA_b', 'Barrels_b', 'Barrel%_b', 'maxEV_b',
#        'HardHit_b', 'HardHit%_b', 'Events_b', 'CStr%_b'],
#       dtype='object', length=634)

# %%
from sklearn.feature_selection import SelectKBest, SelectPercentile, SelectFromModel, mutual_info_regression

# %%
feature_selector = SelectKBest(mutual_info_regression, k = 41)

# %%
df = team_adv_merged[list(team_adv_merged.columns)]

# %%
feature_selector.fit(df, team_adv_merged['Wins'])

# get top features
top_features = df.columns[feature_selector.get_support()]
top_features = top_features.drop(['Wins'])
top_features
# Out:
# Index(['ERA_p', 'SV_p', 'H_p', 'R_p', 'ER_p', 'H/9_p', 'AVG_p', 'WHIP_p',
#        'LOB%_p', 'Starting_p', 'RAR_p', 'WAR_p', 'WPA_p', '-WPA_p', 'RE24_p',
#        'REW_p', 'WPA/LI_p', 'wFB_p', 'wFB/C_p', 'ERA-_p', 'FIP-_p', 'xFIP-_p',
#        'wFA (sc)_p', 'RA9-WAR_p', 'K/BB+_p', 'H/9+_p', 'AVG+_p', 'WHIP+_p',
#        'LOB%+_p', 'K%+_p', 'Bat_b', 'RAR_b', 'WAR_b', 'wRC+_b', 'WPA_b',
#        'RE24_b', 'REW_b', 'WPA/LI_b', 'Off_b', 'OBP+_b'],
#       dtype='object')

# %% [markdown]
# ## Train-Test Split
#
# Define the X as features we want to keep for the Train-Test Split

# %%
team_adv_merged.columns
# Out:
# Index(['Attendance', 'Wins', 'ERA_p', 'G_p', 'GS_p', 'CG_p', 'ShO_p', 'SV_p',
#        'BS_p', 'IP_p',
#        ...
#        'Hard%+_b', 'EV_b', 'LA_b', 'Barrels_b', 'Barrel%_b', 'maxEV_b',
#        'HardHit_b', 'HardHit%_b', 'Events_b', 'CStr%_b'],
#       dtype='object', length=634)

# %%
# feature selection, target variable = 'W'
X = team_adv_merged[list(top_features)]

y = team_adv_merged['Wins']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 42)

# %%
X_train.head(3)
# Out:
#      ERA_p  SV_p     H_p    R_p   ER_p  H/9_p  AVG_p  WHIP_p  LOB%_p  \
# 29    3.03  45.0  1351.0  555.0  495.0   8.27  0.241    1.16   0.749
# 19    3.22  31.0  1269.0  572.0  524.0   7.80  0.230    1.14   0.759
# 135   3.73  49.0  1259.0  659.0  606.0   7.76  0.229    1.24   0.744
#
#      Starting_p  RAR_p  WAR_p  WPA_p  -WPA_p  RE24_p  REW_p  WPA/LI_p  wFB_p  \
# 29        163.1  213.7   24.3  10.34  -94.36   95.55  10.56     10.93   52.3
# 19        118.0  155.4   17.4   3.11  -99.21   73.40   7.94      4.92   44.5
# 135        79.5  137.1   14.5   7.12 -103.84   56.20   5.63      8.52   16.8
#
#      wFB/C_p  ERA-_p  FIP-_p  xFIP-_p  wFA (sc)_p  RA9-WAR_p  K/BB+_p  H/9+_p  \
# 29      0.36    82.0    87.0     93.0        50.6       25.3    135.0    97.0
# 19      0.35    88.0    99.0     95.0        42.2       25.3    114.0    90.0
# 135     0.12    92.0    99.0     99.0        39.2       19.0     99.0    93.0
#
#      AVG+_p  WHIP+_p  LOB%+_p  K%+_p  Bat_b  RAR_b  WAR_b  wRC+_b  WPA_b  \
# 29     98.0     91.0    102.0  104.0   -6.8  238.6   26.2    99.0   4.66
# 19     93.0     89.0    104.0  103.0   16.2  193.5   21.2   102.0   3.89
# 135    95.0     96.0    102.0  104.0   -0.5  278.1   28.6   100.0   7.38
#
#      RE24_b  REW_b  WPA/LI_b  Off_b  OBP+_b
# 29    43.18   4.94      4.03    8.4   100.0
# 19    87.58   9.85      5.10   27.2   101.0
# 135   46.21   4.86      6.08    7.7    99.0

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (157, 40)
# (53, 40)
# (157,)
# (53,)

# %%
# check distribution of features
X_train.hist(figsize = [15,15], bins = 'auto')
plt.show()

# %% [markdown]
# ## Preprocessing Pipeline

# %%
# define numeric columns to be standard scaled
num_cols = X_train.select_dtypes(['int', 'float']).columns

# %%
# define numeric transformation pipeline that scales the numbers
numeric_pipeline = Pipeline([('numnorm', StandardScaler()), # apply a standard scaler
                             ])

# %%
# transform the selected columns with numeric pipelines
adv_teams_ct = ColumnTransformer(transformers = [("numpipe", numeric_pipeline, num_cols)])

# %% [markdown]
# ### Pickle the Transformers

# %%
# save the transformer
dump(adv_teams_ct, open('pkl/adv_teams_ct.pkl', 'wb'))

# %%
# load the transformer
adv_teams_ct = load(open('pkl/adv_teams_ct.pkl', 'rb'))

# %% [markdown]
# **Transform `bb_teams`**

# %%
# inspect the preprocessed batting basic X train aka pp_bb_X_train
pp_X_train = pd.DataFrame(adv_teams_ct.fit_transform(X_train))
pp_X_train.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -1.983110  0.448396 -0.258415 -1.805037 -1.951832 -0.495732 -0.408711
# 1 -1.631576 -1.363323 -1.115627 -1.609492 -1.604234 -1.261325 -1.201795
# 2 -0.687984  0.966030 -1.220165 -0.608761 -0.621371 -1.326482 -1.273894
# 3 -0.521468  0.318988 -0.760198 -0.436221 -0.429592 -0.935541 -0.913401
# 4  1.495228 -1.751548  0.849688  1.634255  1.548120  0.839984  0.889062
#
#          7         8         9         10        11        12        13  \
# 0 -1.520862  0.895940  1.384394  1.418169  1.714580  1.017320  1.690995
# 1 -1.737438  1.371634  0.268739  0.310426  0.468251  0.084308  0.965218
# 2 -0.654557  0.658093 -0.683649 -0.037287 -0.055569  0.601788  0.272363
# 3 -0.979421  0.229969 -0.780125 -0.179793 -0.254259  1.160563  1.068473
# 4  1.619494 -0.103016 -1.789409 -2.579586 -2.494040 -1.795911 -1.593707
#
#          14        15        16        17        18        19        20  \
# 0  1.142709  1.248364  1.269089  1.406818  1.272990 -1.563241 -1.482255
# 1  0.860297  0.919461  0.485037  1.241722  1.245408 -1.010266 -0.047962
# 2  0.640997  0.629475  0.954685  0.655421  0.611021 -0.641616 -0.047962
# 3  0.616007  0.595581  0.684638  0.445877  0.445529 -0.549453  0.310611
# 4 -1.739168 -1.730587 -2.251968 -2.369215 -2.119600  1.570286  2.820623
#
#          21        22        23        24        25        26        27  \
# 0 -0.840102  1.420463  1.328876  1.917568 -0.343662 -0.268691 -1.225554
# 1 -0.582492  1.176307  1.328876  0.693517 -1.386989 -1.218794 -1.519313
# 2 -0.067274  1.089109  0.500548 -0.180805 -0.939848 -0.838753 -0.491157
# 3  0.061531  0.176433  0.579436 -0.239093 -0.939848 -1.028774 -1.078675
# 4  2.122405 -2.788310 -1.405922 -1.463143  0.699665  0.681411  1.418275
#
#          28        29        30        31        32        33        34  \
# 0  0.532825  0.335609  0.243136  0.632598  0.856854  0.237774  0.934884
# 1  1.215712  0.232697  0.581401  0.066208  0.234163  0.571082  0.817072
# 2  0.532825  0.335609  0.335791  1.128661  1.155746  0.348877  1.351050
# 3  0.191382 -0.899326  1.652081  1.377320  1.417276  1.682110  0.918054
# 4 -0.150061 -0.899326 -0.915787 -1.023873 -1.048579 -0.873253 -0.013731
#
#          35        36        37        38        39
# 0  0.559958  0.639366  0.651314  0.460434  0.355127
# 1  1.204176  1.338629  0.811442  0.731430  0.624475
# 2  0.603922  0.627973  0.958102  0.450344  0.085780
# 3  1.288040  1.332933  1.308289  1.538651  0.893823
# 4 -0.263451 -0.314821 -0.849704 -0.956528 -0.722264

# %%
pp_X_train.shape
# Out:
# (157, 40)

# %% [markdown]
# Now lets do the same transformation for the `X_test`

# %%
# inspect the preprocessed batting basic X train aka pp_bb_X_test
pp_X_test = pd.DataFrame(adv_teams_ct.transform(X_test))
pp_X_test.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.095927  0.318988  0.776511  0.012382  0.025881  0.530489  0.528569
# 1  0.977178  0.707213  0.191098  0.886583  0.948814  0.302440  0.095978
# 2 -0.761991  0.189579 -0.446584 -0.930835 -0.705274 -0.577178 -0.480810
# 3 -0.151432 -0.328055 -0.143424 -0.286687 -0.213842 -0.039634 -0.120317
# 4  1.828261 -1.363323  1.957791  2.048350  1.955649  1.817338  1.754244
#
#          7         8         9         10        11        12        13  \
# 0  0.320036  0.325108 -0.973076 -0.810618 -0.760016 -0.025382 -0.387570
# 1 -0.004828 -1.434959 -0.191376  0.243924  0.070870 -0.448657 -0.698831
# 2 -0.979421  0.610524  0.389952 -0.092390 -0.109757  0.781164 -0.191536
# 3 -0.437981  0.325108  0.689274  0.147020  0.052808 -0.132491 -0.059848
# 4  2.052646 -2.053361 -0.532751 -0.818218 -0.850330 -1.597178 -2.530483
#
#          14        15        16        17        18        19        20  \
# 0  0.057176  0.060801 -0.284664 -0.921453 -0.795662 -0.088640  0.908233
# 1 -0.752320 -0.653495 -0.747789  0.348513  0.335201  1.017310 -0.406535
# 2  0.836200  0.852928  0.965122  0.892481  0.914423 -0.733778 -0.406535
# 3  0.279026  0.276721  0.169329  0.185534  0.169709 -0.272966 -0.167486
# 4 -1.634109 -1.546050 -1.109157 -1.844295 -1.595541  1.570286  1.027757
#
#          21        22        23        24        25        26        27  \
# 0  0.705554 -0.410702  0.027217 -0.647110  0.401572  0.301370  0.390119
# 1 -0.324883 -0.401982 -1.024628  0.868382  0.401572  0.111350 -0.197398
# 2 -0.324883  0.673464  0.605732  0.926670 -0.790802 -0.648733 -1.225554
# 3  0.319140  0.138647  0.237586  0.576941  0.252525  0.301370 -0.344278
# 4  0.705554 -1.241993 -1.695179 -0.938550  1.742992  1.631514  1.858913
#
#          28        29        30        31        32        33        34  \
# 0  0.191382 -0.693504 -0.184842  0.188026  0.283979 -0.206637 -0.429898
# 1 -1.515834  0.232697 -0.980498 -0.969871 -1.061033 -0.873253 -1.305072
# 2  0.874268  0.129786 -0.127484  0.589899  0.582870 -0.095534 -0.162144
# 3  0.532825 -0.590593  0.518160  0.554735  0.495693  0.571082  0.768111
# 4 -1.857277 -0.487681 -0.503987 -0.339433 -0.351166 -0.428842 -0.096353
#
#          35        36        37        38        39
# 0 -0.050888 -0.078410  0.157460  0.003489  0.355127
# 1 -0.950037 -0.999842 -0.700051 -1.117973 -1.530308
# 2  0.090143  0.145183 -0.049061 -0.162280  0.355127
# 3  0.375688  0.373048  0.326567  0.679537  0.355127
# 4 -0.310026 -0.386029 -0.028110 -0.235795 -0.452916

# %%
pp_X_test.shape
# Out:
# (53, 40)

# %% [markdown]
# **Log Transforming Wins**

# %%
# basic y
log_y_train = np.log(y_train)
log_y_test = np.log(y_test)

# %% [markdown]
# ## Modeling

# %%
# import my helper function to get model results
from functions import *

# %% [markdown]
# ### Linear Regression

# %%
# build pipeline 
steps = [('preprocess', adv_teams_ct), 
         ('model', LinearRegression())]

lin_reg_pipeline = Pipeline(steps)

lin_reg_pipeline.fit(X_train, log_y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('numpipe',
#                                                   Pipeline(steps=[('numnorm',
#                                                                    StandardScaler())]),
#                                                   Index(['ERA_p', 'SV_p', 'H_p', 'R_p', 'ER_p', 'H/9_p', 'AVG_p', 'WHIP_p',
#        'LOB%_p', 'Starting_p', 'RAR_p', 'WAR_p', 'WPA_p', '-WPA_p', 'RE24_p',
#        'REW_p', 'WPA/LI_p', 'wFB_p', 'wFB/C_p', 'ERA-_p', 'FIP-_p', 'xFIP-_p',
#        'wFA (sc)_p', 'RA9-WAR_p', 'K/BB+_p', 'H/9+_p', 'AVG+_p', 'WHIP+_p',
#        'LOB%+_p', 'K%+_p', 'Bat_b', 'RAR_b', 'WAR_b', 'wRC+_b', 'WPA_b',
#        'RE24_b', 'REW_b', 'WPA/LI_b', 'Off_b', 'OBP+_b'],
#       dtype='object'))])),
#                 ('model', LinearRegression())])

# %%
# instantiate the model
lr_model = Pipeline(steps).steps[1][1]  # gets the class name of the model

# get model results
model_results(lr_model, pp_X_train, log_y_train, pp_X_test, log_y_test)
# Out:
#              LinearRegression() RESULTS
# LinearRegression() Training R2:               0.9947
# LinearRegression() Test R2:                   0.9819
# -------------------------------------------------------
# LinearRegression() Cross Validation R2:       0.9888
# LinearRegression() Cross Validation RMSE:    0
# -------------------------------------------------------
# LinearRegression() Training RMSE:            1
# LinearRegression() Test RMSE:                1

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=30) # Check out how `n_components` works

X_train_pca = pca.fit_transform(pp_X_train)
X_test_pca = pca.transform(pp_X_test)

# %%
lr_pca = LinearRegression()

# get model results
model_results(lr_pca, X_train_pca, log_y_train, X_test_pca, log_y_test)
# Out:
#              LinearRegression() RESULTS
# LinearRegression() Training R2:               0.9931
# LinearRegression() Test R2:                   0.983
# -------------------------------------------------------
# LinearRegression() Cross Validation R2:       0.988
# LinearRegression() Cross Validation RMSE:    0
# -------------------------------------------------------
# LinearRegression() Training RMSE:            1
# LinearRegression() Test RMSE:                1

# %%
lr_pca.coef_
# Out:
# array([ 0.02731902,  0.01218507,  0.00134238,  0.03715118, -0.00219849,
#        -0.01350206, -0.01994253,  0.01630017, -0.02883114, -0.03749077,
#         0.00334406,  0.00803534, -0.02135537, -0.00889219,  0.01267504,
#         0.02475513, -0.00042836,  0.05996318,  0.05574784, -0.01280572,
#        -0.05244904, -0.01253838,  0.00739468,  0.01491098,  0.01343716,
#         0.01822495, -0.00056463,  0.05000106,  0.00357641,  0.02074616])

# %% [markdown]
# ### KNeighbors Regression

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
# build pipeline 
steps = [('preprocess', adv_teams_ct), 
         ('model', KNeighborsRegressor())]

knr_pipeline = Pipeline(steps)

# define parameters in the grid
knr_grid = {
            'model__n_neighbors': [10],
            'model__metric': ['minkowski', 'l1', 'l2']
           }  

# get best R2 score from grid search
knr_model = GridSearchCV(estimator = knr_pipeline,
                         param_grid = knr_grid,
                         scoring = 'r2')

knr_pipeline.fit(X_train, log_y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('numpipe',
#                                                   Pipeline(steps=[('numnorm',
#                                                                    StandardScaler())]),
#                                                   Index(['ERA_p', 'SV_p', 'H_p', 'R_p', 'ER_p', 'H/9_p', 'AVG_p', 'WHIP_p',
#        'LOB%_p', 'Starting_p', 'RAR_p', 'WAR_p', 'WPA_p', '-WPA_p', 'RE24_p',
#        'REW_p', 'WPA/LI_p', 'wFB_p', 'wFB/C_p', 'ERA-_p', 'FIP-_p', 'xFIP-_p',
#        'wFA (sc)_p', 'RA9-WAR_p', 'K/BB+_p', 'H/9+_p', 'AVG+_p', 'WHIP+_p',
#        'LOB%+_p', 'K%+_p', 'Bat_b', 'RAR_b', 'WAR_b', 'wRC+_b', 'WPA_b',
#        'RE24_b', 'REW_b', 'WPA/LI_b', 'Off_b', 'OBP+_b'],
#       dtype='object'))])),
#                 ('model', KNeighborsRegressor())])

# %%
# instantiate the model
knr_model = Pipeline(steps).steps[1][1]  # gets the class name of the model

# get model results
model_results(knr_model, pp_X_train, log_y_train, pp_X_test, log_y_test)
# Out:
#              KNeighborsRegressor() RESULTS
# KNeighborsRegressor() Training R2:               0.9222
# KNeighborsRegressor() Test R2:                   0.8767
# -------------------------------------------------------
# KNeighborsRegressor() Cross Validation R2:       0.8452
# KNeighborsRegressor() Cross Validation RMSE:    5
# -------------------------------------------------------
# KNeighborsRegressor() Training RMSE:            3
# KNeighborsRegressor() Test RMSE:                4

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn import svm
from sklearn.svm import LinearSVR

# %%
# build pipeline 
svm_steps = [('preprocess', adv_teams_ct),
            ('model', svm.SVR())]

svm_pipeline = Pipeline(svm_steps)

# define parameters in the grid
svm_grid = {
            'model__kernel': ['rbf', 'linear', 'poly', 'sigmoid'],
            'model__C': [10]
           }  

# get best R2 score from grid search
svm_model = GridSearchCV(estimator = svm_pipeline,
                         param_grid = svm_grid,
                         scoring = 'r2')

# fit and give me the best params
svm_model.fit(X_train, log_y_train)
svm_model.best_params_
# Out:
# {'model__C': 10, 'model__kernel': 'linear'}

# %%
# instantiate the model
svm_model = svm_pipeline.steps[1][1]  # gets the class name of the model

# get model results
model_results(svm_model, pp_X_train, log_y_train, pp_X_test, log_y_test)
# Out:
#              SVR() RESULTS
# SVR() Training R2:               0.8833
# SVR() Test R2:                   0.8378
# -------------------------------------------------------
# SVR() Cross Validation R2:       0.7961
# SVR() Cross Validation RMSE:    7
# -------------------------------------------------------
# SVR() Training RMSE:            5
# SVR() Test RMSE:                5

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# build pipeline 
rfr_steps = [('preprocess', adv_teams_ct), 
            ('model', RandomForestRegressor(random_state = 42))]

rfr_pipeline = Pipeline(rfr_steps)

# define parameters in the grid
rfr_grid = {'model__n_estimators': [100],
            'model__max_depth': [10],
            'model__min_samples_split': [2],
            'model__min_samples_leaf': [2, 3, 4]
           }  

# get best R2 score from grid search
rfr_model = GridSearchCV(estimator = rfr_pipeline,
                           param_grid = rfr_grid,
                           scoring = 'r2')

# fit and give me the best params
rfr_model.fit(X_train, log_y_train)
rfr_model.best_params_
# Out:
# {'model__max_depth': 10,
#  'model__min_samples_leaf': 2,
#  'model__min_samples_split': 2,
#  'model__n_estimators': 100}

# %%
# instantiate the model
rfr_model = rfr_pipeline.steps[1][1]  # gets the name of the model

# get model results
model_results(rfr_model, pp_X_train, log_y_train, pp_X_test, log_y_test)
# Out:
#              RandomForestRegressor(random_state=42) RESULTS
# RandomForestRegressor(random_state=42) Training R2:               0.9931
# RandomForestRegressor(random_state=42) Test R2:                   0.9376
# -------------------------------------------------------
# RandomForestRegressor(random_state=42) Cross Validation R2:       0.9249
# RandomForestRegressor(random_state=42) Cross Validation RMSE:    3
# -------------------------------------------------------
# RandomForestRegressor(random_state=42) Training RMSE:            1
# RandomForestRegressor(random_state=42) Test RMSE:                3

# %% [markdown]
# **CatBoost**

# %%
from catboost import CatBoostRegressor

# %%
# build pipeline 
cbr_steps = [('preprocess', adv_teams_ct), 
            ('model', CatBoostRegressor(random_state = 42,
                                        allow_writing_files=False, 
                                        verbose = False))]

cbr_pipeline = Pipeline(cbr_steps)

# define parameters in the grid
cbr_grid = {
                'model__learning_rate': [0.1],
                'model__iterations': [100],
                'model__max_depth': [5],
                'model__l2_leaf_reg': [1]
               }  

# get best R2 score from grid search
cbr_model = GridSearchCV(estimator = cbr_pipeline,
                         param_grid = cbr_grid,
                         scoring = 'r2')

# fit and give me the best params
cbr_model.fit(X_train, log_y_train)
cbr_model.best_params_
# Out:
# {'model__iterations': 100,
#  'model__l2_leaf_reg': 1,
#  'model__learning_rate': 0.1,
#  'model__max_depth': 5}

# %%
# instantiate the model
cbr_model = cbr_pipeline.steps[1][1]  # gets the class name of the model

# get model results
model_results(cbr_model, pp_X_train, log_y_train, pp_X_test, log_y_test)
# Out:
#              <catboost.core.CatBoostRegressor object at 0x13ea8f7f0> RESULTS
# <catboost.core.CatBoostRegressor object at 0x13ea8f7f0> Training R2:               1.0
# <catboost.core.CatBoostRegressor object at 0x13ea8f7f0> Test R2:                   0.9528
# -------------------------------------------------------
# <catboost.core.CatBoostRegressor object at 0x13ea8f7f0> Cross Validation R2:       0.9319
# <catboost.core.CatBoostRegressor object at 0x13ea8f7f0> Cross Validation RMSE:    3
# -------------------------------------------------------
# <catboost.core.CatBoostRegressor object at 0x13ea8f7f0> Training RMSE:            0
# <catboost.core.CatBoostRegressor object at 0x13ea8f7f0> Test RMSE:                2

# %% [markdown]
# # Visualize the Model Fit on Test Set
#
# ### Predicted Linear Regression Plots & Residuals

# %%
# get residuals
y_pred_test = lr_model.predict(pp_X_test)
resid = y_test - np.exp(y_pred_test)

# %%
sns.set_style("dark")

# plots TESTING set & residuals
fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# plots regplots
sns.regplot(ax = axes[0], 
            x = np.exp(y_pred_test), 
            y = y_test,
            scatter_kws={'s':5, 'alpha': 0.2, 'color': 'darkgreen'},
            line_kws={"color": "red"})

# annotate regplot
axes[0].text(50, 105, "Testing R2 = 0.98", 
             horizontalalignment='left', fontsize=13, color='black', weight = 'bold')

# regplot labels
axes[0].set_xlabel('Predicted Wins', weight = 'bold') 
axes[0].set_ylabel('Actual Wins', weight = 'bold') 
axes[0].set_title('Predicted Wins VS. Actual', weight = 'bold', fontdict = {'fontsize' : 15})

# plots residual
sns.scatterplot(ax = axes[1], 
                x = range(y_test.shape[0]),
                y = resid, 
                alpha=0.5,
                color= "darkgreen")
# plot zero line in residual
sns.lineplot(ax = axes[1], 
             x=range(y_test.shape[0]), y = 0, 
             color='red', linestyle="dashed", linewidth = 3)

# residual labels
axes[1].set_xlabel('Count', weight = 'bold') 
axes[1].set_ylabel('Win Residuals', weight = 'bold') 
axes[1].set_title('Testing Set Residuals', weight = 'bold', fontdict = {'fontsize' : 15})

# removes top and right side axis
sns.despine(right = True)

# set gridline visibility
axes[0].set_axisbelow(True)
axes[0].yaxis.grid(True, color='#EEEEEE')
axes[0].xaxis.grid(False)
axes[1].set_axisbelow(True)
axes[1].yaxis.grid(True, color='#EEEEEE')
axes[1].xaxis.grid(False)

plt.show()
fig.savefig('plots/team_adv_resids.png');

# %% [markdown]
# ### Assessing the Important Features
#
# Lets now assess which features in the Linear Regression model are the most important when making a prediction.

# %%
top_features
# Out:
# Index(['ERA_p', 'SV_p', 'H_p', 'R_p', 'ER_p', 'H/9_p', 'AVG_p', 'WHIP_p',
#        'LOB%_p', 'Starting_p', 'RAR_p', 'WAR_p', 'WPA_p', '-WPA_p', 'RE24_p',
#        'REW_p', 'WPA/LI_p', 'wFB_p', 'wFB/C_p', 'ERA-_p', 'FIP-_p', 'xFIP-_p',
#        'wFA (sc)_p', 'RA9-WAR_p', 'K/BB+_p', 'H/9+_p', 'AVG+_p', 'WHIP+_p',
#        'LOB%+_p', 'K%+_p', 'Bat_b', 'RAR_b', 'WAR_b', 'wRC+_b', 'WPA_b',
#        'RE24_b', 'REW_b', 'WPA/LI_b', 'Off_b', 'OBP+_b'],
#       dtype='object')

# %%
# get feature weights
best_model_coef = lr_model.coef_
best_model_coef
# Out:
# array([-0.22546123,  0.0011198 , -0.12736771,  0.00969807,  0.19191064,
#         0.11137993,  0.02500254, -0.00316911, -0.0058906 , -0.00342585,
#        -0.03271932,  0.02171661,  0.10227706, -0.00490139,  0.02334985,
#         0.00023954, -0.01123335,  0.07572657, -0.07577049,  0.02029911,
#         0.00264607, -0.00173925,  0.00424657,  0.01544668, -0.00952947,
#         0.02361038, -0.011039  , -0.00882125, -0.00901475,  0.01428991,
#        -0.03283825,  0.07278142, -0.07735231,  0.02810863,  0.08450174,
#        -0.01164324,  0.01586916, -0.00418026,  0.01026084, -0.00183525])

# %%
# check feature importances
feat_imp_series = pd.Series(best_model_coef, 
                            index = pp_X_train.columns)

# preview first 5
feat_imp_series[:5]
# Out:
# 0   -0.225461
# 1    0.001120
# 2   -0.127368
# 3    0.009698
# 4    0.191911
# dtype: float64

# %% [markdown]
# We need to index these importance features values with their appropriate values to make sense of which Importance value is associated with which Feature. We'll merge the `top_features_df` with the `feat_imp_df`.

# %%
top_features_list = list(top_features)
top_features_df = pd.DataFrame(top_features_list)
top_features_df.head()
# Out:
#        0
# 0  ERA_p
# 1   SV_p
# 2    H_p
# 3    R_p
# 4   ER_p

# %%
# convert feat_imp_series into a df
feat_imp_df = pd.DataFrame(feat_imp_series)
feat_imp_df.head()
# Out:
#           0
# 0 -0.225461
# 1  0.001120
# 2 -0.127368
# 3  0.009698
# 4  0.191911

# %%
# merge the feature names and feature importance dataframes based on index
merged = pd.merge(top_features_df, feat_imp_df, left_index=True, right_index=True)

# rename the new merged dataframe
merged = merged.rename(columns = {'0_x': 'Feature', '0_y': 'Importance'})
merged.head()
# Out:
#   Feature  Importance
# 0   ERA_p   -0.225461
# 1    SV_p    0.001120
# 2     H_p   -0.127368
# 3     R_p    0.009698
# 4    ER_p    0.191911

# %%
# sort by top 15 most important features
sorted_features = merged.sort_values('Importance', ascending = False)

# create a top 15 features df
top_15_features = sorted_features.head(15)
top_15_features
# Out:
#       Feature  Importance
# 4        ER_p    0.191911
# 5       H/9_p    0.111380
# 12      WPA_p    0.102277
# 34      WPA_b    0.084502
# 17      wFB_p    0.075727
# 31      RAR_b    0.072781
# 33     wRC+_b    0.028109
# 6       AVG_p    0.025003
# 25     H/9+_p    0.023610
# 14     RE24_p    0.023350
# 11      WAR_p    0.021717
# 19     ERA-_p    0.020299
# 36      REW_b    0.015869
# 23  RA9-WAR_p    0.015447
# 29      K%+_p    0.014290

# %%
# plot a lollipop plot of top 15 most important features
fig, ax = plt.subplots(figsize=(18, 8))
plt.style.use('bmh')

# sort by descending
top_15_features= top_15_features.sort_values(by = 'Importance')

# plots the lines
plt.hlines(y = top_15_features['Feature'],  # feature
           xmin = 0,
           xmax = top_15_features['Importance'],  # importance
           color = '#013369', linewidth = 3)

plt.scatter(top_15_features['Importance'], # Count values
            top_15_features['Feature'],  # positions
            color='#d50a0a', 
            alpha=1, s = 50)

# annotate the scatter plot values
for idx, row in top_15_features.iterrows():
    ax.annotate(round(row['Importance'],4), (row['Importance'], row['Feature'] ), 
                weight = "bold", fontsize = 11, 
                xytext=(row['Importance'] + 0.002, row['Feature'])) # offset annotate

plt.title('Top 15 Most Importance Features (Linear Regression)', weight = "bold", fontsize = 16)
plt.ylabel('Feature', weight = "bold", fontsize = 14)
plt.xlabel('Coefficient Weight', weight = "bold", fontsize = 14)

plt.tight_layout()
plt.show()
# fig.savefig('images/top_team_important_features.png');
